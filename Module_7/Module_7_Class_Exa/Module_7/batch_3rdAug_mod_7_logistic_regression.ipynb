# %% [markdown]
# # Case Study: Cancer benign or malignant

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# in production don't use full import for sklearn as it is heavy
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
# setting to display maximum rows and columns when you print it.
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 1000)

# %%
# 1. data collection
cancer = pd.read_csv('./Datasets/data.csv')
cancer.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# 2. data wrangling

# %%
cancer = cancer.drop('Unnamed: 32', axis=1)
cancer.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# id of patient is of no use
cancer.drop('id', axis=1, inplace=True)
cancer.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# ...

# %%
# encoding the output from string to number
cancer['diagnosis'] = cancer['diagnosis'].map({'M':1, 'B':0})
cancer.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# ...

# %%
sns.heatmap(cancer.corr().round(1), annot=True)
plt.show()

# %%
list(cancer.columns)
# Out:
# ['diagnosis',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst']

# %%
prediction_var = ['radius_mean', 'texture_mean', 'perimeter_mean',
                  'area_mean', 'smoothness_mean','compactness_mean',
                  'concavity_mean', 'concave points_mean',
                  'symmetry_mean','fractal_dimension_mean']
# taking mean values as that is a better estimate
cancer_select = cancer[prediction_var]
cancer_select
sns.heatmap(cancer_select.corr().round(1), annot=True)
plt.show()

# %%
# Inference drawn from the correlation maxtrix: perimeter_mean,
# ..area_mean and radius_mean are highly correlated and having
# ..pearson'e correlation coefficient of +1, so we can drop two columns

# %%
cancer_select.drop(['perimeter_mean', 'area_mean'],
            inplace=True,
            axis=1)
cancer_select.head()
# Out:
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#    radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0        17.99         10.38          0.11840           0.27760
# 1        20.57         17.77          0.08474           0.07864
# 2        19.69         21.25          0.10960           0.15990
# 3        11.42         20.38          0.14250           0.28390
# 4        20.29         14.34          0.10030           0.13280
#
#    concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean
# 0          0.3001              0.14710         0.2419                 0.07871
# 1          0.0869              0.07017         0.1812                 0.05667
# ...

# %%
# 3. data analysis
cancer_select.describe()
# Out:
#        radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# count   569.000000    569.000000       569.000000        569.000000
# mean     14.127292     19.289649         0.096360          0.104341
# std       3.524049      4.301036         0.014064          0.052813
# min       6.981000      9.710000         0.052630          0.019380
# 25%      11.700000     16.170000         0.086370          0.064920
# 50%      13.370000     18.840000         0.095870          0.092630
# 75%      15.780000     21.800000         0.105300          0.130400
# max      28.110000     39.280000         0.163400          0.345400
#
#        concavity_mean  concave points_mean  symmetry_mean  \
# count      569.000000           569.000000     569.000000
# mean         0.088799             0.048919       0.181162
# std          0.079720             0.038803       0.027414
# min          0.000000             0.000000       0.106000
# 25%          0.029560             0.020310       0.161900
# ...

# %%
sns.countplot(cancer['diagnosis'])

# %%
# train the model
train, test = train_test_split(cancer,
                               test_size=0.30)
print(train.shape)
print(test.shape)
# Out:
# (398, 31)
# (171, 31)

# %%
# select the relevant columns
prediction_var.remove('perimeter_mean')  # as it is having high correlation with radius_mean
prediction_var.remove('area_mean')

train_X = train[prediction_var]
train_Y = train['diagnosis']

test_X = train[prediction_var]
test_Y = train['diagnosis']

# %%
# training the model
log_model = LogisticRegression()
# training the model
log_model.fit(train_X, train_Y)

# testing the model
y_pred = log_model.predict(test_X)
# Out:
# //anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
accuracy = metrics.accuracy_score(test_Y, y_pred)
accuracy
# Out:
# 0.8969849246231156

# %%
# means the accuracy of the model is 89%

# %%
df = pd.DataFrame({'predicted_value': y_pred, 'actual_value':test_Y})
df
# Out:
#      predicted_value  actual_value
# 496                0             0
# 312                0             0
# 133                0             0
# 85                 1             1
# 514                0             1
# 423                0             0
# 36                 0             1
# 554                0             0
# 405                0             0
# 557                0             0
# 561                0             0
# 89                 0             0
# 261                1             1
# 129                1             1
# 351                1             1
# 265                1             1
# 543                0             0
# 69                 0             0
# 150                0             0
# 121                1             1
# 191                0             0
# 51                 0             0
# 478                0             0
# 474                0             0
# 46                 0             0
# 15                 1             1
# ...
